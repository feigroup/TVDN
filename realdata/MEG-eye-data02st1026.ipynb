# %%
import sys
sys.path.append("/home/huaqingj/MyResearch/TVDN")

# %%
from pyTVDN import TVDNDetect, TVDNRankTuning
from pathlib import Path
from scipy.io import loadmat
from scipy.signal import detrend
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pyTVDN.tmpUtils import *
# %matplotlib inline

# %%
from pprint import pprint
import pickle
from easydict import EasyDict as edict
import warnings
from pyTVDN.TVDNutils import *
from pyTVDN.utils import in_notebook
if in_notebook():
    from tqdm import tqdm_notebook as tqdm
else:
    from tqdm import tqdm

class TVDNDetect1(TVDNDetect):
    def SmoothEst(self):
        if self.nYmat is None:
            self._Preprocess()
        d, n = self.nYmat.shape
        acTime = n / self.paras.freq
        self.ptime = np.linspace(0, acTime, n)
        self.time = np.linspace(0, self.paras.T, n)
        divNum = 100
        if self.smoothType == "bspline":
            self.dXmat = np.zeros((d, n))
            self.Xmat = np.zeros((d, n))
            if n%divNum == 0:
                numLoop = int(n/divNum)
            else:
                numLoop = int(n/divNum) + 1
            for i in range(numLoop):
                if (i+1)*divNum <= n:
                    low = i*divNum
                    up = (i+1)*divNum
                else:
                    low = i*divNum
                    up = n
                self.dXmat[:, low:up], self.Xmat[:, low:up] = GetBsplineEst(self.nYmat[:, low:up], self.time[low:up], 
                                                                            lamb=self.paras.lamb)
        elif self.smoothType == "fourier":
            self.dXmat, self.Xmat = GetFourierEst(self.nYmat, self.time, nbasis=self.paras.nbasis)
            
    def PlotEigenCurve(self, mfct=1, saveFigPath=None):
        assert self.finalRes is not None, "Run main function first!"
        if self.RecResCur is None:
            self.GetRecResCur()
        freq = self.paras.freq
        numChgCur = len(self.ecpts)
        LamMs = self.RecResCur.LamMs
        rAct, n = LamMs.shape
        pltIdxs = np.arange(1, rAct)[np.diff(np.abs(LamMs), axis=0).astype(np.bool).all(axis=1)] 
        pltIdxs = np.concatenate([[0], pltIdxs])
        acTime = n / self.paras.freq
        ReLamMs = mfct * LamMs.real/(acTime/self.paras.T)
        ImLamMs = mfct * LamMs.imag/((2*np.pi)*(acTime/self.paras.T))
        cols = sns.color_palette("Paired", len(pltIdxs))
        
        plt.figure(figsize=[10, 5])
        plt.subplots_adjust(wspace=0.5, hspace=0.5)
        plt.subplot(121)
        for i0, i in enumerate(pltIdxs):
            labs = f"$\\lambda_{i0+1}$"
            plt.plot(self.ptime, np.abs(ReLamMs[i, :]), label=labs, 
                     color=cols[i0], linewidth=2)
        plt.ylabel("Change of growth/decay constant")
        plt.xlabel("Time")
        #_ = plt.legend()
        _ = plt.legend(loc="upper left")
        
        plt.subplot(122)
        for i0, i in enumerate(pltIdxs):
            labs = f"$\\lambda_{i0+1}$"
            plt.plot(self.ptime, np.abs(ImLamMs[i, :]), label=labs, 
                     color=cols[i0], linewidth=2)
        plt.ylabel("Change of frequencyy")
        plt.xlabel("Time")
        # _ = plt.legend()
        _ = plt.legend(loc="upper left")
        if saveFigPath is None:
            plt.show() 
        else:
            plt.savefig(saveFigPath)

# %%
resDir = Path("../results")
dataDir = Path("../data/newMEGdata")

# %%
datFil = list(dataDir.glob("*02*min.mat"))[0]
datFil
# Out:
# PosixPath('../data/newMEGdata/lcmv_result_R2868E_02-st_wo_filtering_min.mat')

# %%
gtF = list(dataDir.glob("*02_st.txt"))[0]
gtSt02 = time2pts(txt2Time(gtF), timeLims.st02)

# %%
np.diff(gtSt02.cpts)
# Out:
# array([1034, 1345, 1392, 1253, 1365])

# %%
from scipy.signal import lfilter, firls, decimate

# %%
q = 10

# %% [markdown]
# ## Plot the data

# %%
MEG = loadmat(datFil)

# %%
data = MEG["DK_timecourse"]

# %% [markdown]
# The time course is 60 seconds, so the frequency is 1200 Hz

# %%
d, n = data.shape

# %% [markdown]
# ###  Data preprocessing

# %%
dataN = decimate(data, q=q)
dataN = detrend(dataN)

# %% [markdown]
# ### HPF

# %%
fs = 120 #sampling frequency
fmin = 2 # 2Hz - 45Hz signal range, filter for this with hbp
fmax = 45
hbp = firls(101, np.array([0, 0.2*fmin, 0.9*fmin, fmax-2, fmax+5, 60])*2/fs,
           desired = np.array([0, 0, 1, 1, 0, 0])) #for detrending, a bandpass

# %%
dataHPF = lfilter(hbp, 1, dataN)

# %% [markdown]
# ## Detection on data with screening and no HPF

# %%
paras = edict()
paras.Lmin = 200
paras.wh = 10
paras.MaxM = 20
paras.fct = 0.5
paras.r = 12 
paras.freq = 120
paras.lamb = 1e-4
paras.T = 2
paras.is_detrend = False
paras.decimateRate = None
paras.kappa = 1
paras.downRate = 20

# %% [markdown]
# **Best**
#
# wh = 10
#
# numChg = 6
#
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'MEG1',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 1,
#  'lamb': 0.0001/0.0005,
#  'nbasis': 10,
#  'r': 6/8/12}

# %%
detRaw = TVDNDetect1(Ymat=dataN, dataType="MEG", 
                     saveDir=None, #"MEGst02", 
                     fName="MEG1",
                     showProgress=True, 
                     MaxM=paras.MaxM,
                     Lmin=paras.Lmin, 
                     lamb=paras.lamb, 
                     kappa=paras.kappa, 
                     freq=paras.freq,
                     r=paras.r,
                     T=paras.T,
                     is_detrend=paras.is_detrend,
                     decimateRate=paras.decimateRate, 
                     downRate=paras.downRate)
# Out:
# The parameters for detection are:
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'MEG1',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 1,
#  'lamb': 0.0001,
#  'nbasis': 10,
#  'r': 12}

# %%
detRaw.Screening(wh=paras.wh)
detRaw()
# Out:
# HBox(children=(IntProgress(value=0, description='Screening', max=7200, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=374, style=ProgressStyle(descriptio…

# %%
kappas = np.linspace(1, 4, 1000)
detRaw.TuningKappa(kappas)
# Out:
# HBox(children=(IntProgress(value=0, max=21), HTML(value='')))

# %%
detRaw.UpdateEcpts(6)
print(detRaw)
detRaw.PlotEcpts(GT=gtSt02.cpts)
# Out:
# +-------------+---------------------------------------+-------------------+------+
# | Num of CPTs |             Estiamted CPTs            |        MSE        | Rank |
# +-------------+---------------------------------------+-------------------+------+
# |      6      | [ 500. 1577. 3019. 4325. 5599. 6974.] | 6.246913720619532 |  12  |
# +-------------+---------------------------------------+-------------------+------+

# %%
detRaw.PlotEigenCurve()

# %%
detRaw.PlotEigenCurve(mfct=120)

# %%
detRaw.kappas[detRaw.numchgs==6]
# Out:
# array([1.62462462, 1.62762763, 1.63063063, 1.63363363, 1.63663664])

# %% [markdown]
# ## Detection on data with no  HPF and no screening

# %%
detRawNo = TVDNDetect1(Ymat=dataN, dataType="MEG", 
                     saveDir="MEGeye-st02", 
                     fName="MEGmin",
                     showProgress=True, 
                     MaxM=paras.MaxM,
                     Lmin=paras.Lmin, 
                     lamb=paras.lamb, 
                     kappa=paras.kappa, 
                     freq=paras.freq,
                     r=paras.r,
                     T=paras.T,
                     is_detrend=paras.is_detrend,
                     decimateRate=paras.decimateRate, 
                     downRate=paras.downRate)
# Out:
# The parameters for detection are:
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'MEGmin',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 1,
#  'lamb': 0.0001,
#  'nbasis': 10,
#  'r': 12}

# %%
detRawNo()
# Out:
# /home/huaqingj/MyResearch/TVDN/pyTVDN/TVDNclass.py:266: UserWarning: As loading the saved results, kappa will be ignored
#   warnings.warn("As loading the saved results, kappa will be ignored", UserWarning)

# %%
kappas = np.linspace(1, 4, 1000)
detRawNo.TuningKappa(kappas)

# %%
detRawNo.UpdateEcpts(6)
print(detRawNo)
detRawNo.PlotEcpts(GT=gtSt02.cpts)
# Out:
# +-------------+---------------------------------------+-------------------+------+
# | Num of CPTs |             Estiamted CPTs            |        MSE        | Rank |
# +-------------+---------------------------------------+-------------------+------+
# |      6      | [ 500. 1589. 3016. 4351. 5535. 6984.] | 6.891189268764603 |  12  |
# +-------------+---------------------------------------+-------------------+------+

# %%
detRawNo.PlotEigenCurve()

# %%
detRawNo.PlotEigenCurve(mfct=120)

# %%
detRawNo.kappas[detRawNo.numchgs==6]
# Out:
# array([1.63363363, 1.63663664, 1.63963964])
