# %%
import sys
sys.path.append("/home/huaqingj/MyResearch/TVDN")

# %%
from pyTVDN import TVDNDetect
from pathlib import Path
from scipy.io import loadmat
from scipy.signal import detrend
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from scipy.signal import lfilter, firls, decimate

# %%
from pprint import pprint
import pickle
from easydict import EasyDict as edict
import warnings
from pyTVDN.TVDNutils import *
from pyTVDN.utils import in_notebook
if in_notebook():
    from tqdm import tqdm_notebook as tqdm
else:
    from tqdm import tqdm

class TVDNDetect1(TVDNDetect):
    def TuningKappaNew(self, kappas):
        assert self.finalRes is not None, "Run main function first!"
        
        MaxM = self.paras.MaxM
        U0 = self.finalRes.U0 
        rAct, n = self.midRes.nXmat.shape
        r = self.paras.r
        Us = []
        for kappac in kappas:
            Us.append(U0 + 2*r*np.log(n)**kappac* (np.arange(1, MaxM+2)))
        Us = np.array(Us)
        numchgs = Us.argmin(axis=1)
        self.numchgs = numchgs
        argIdx = np.argmin(np.diff(numchgs)/np.diff(kappas))
        
        self.Us = Us
        mUs = Us.min(axis=1)
        argmU = np.argmin(mUs)
        
        chgsKappas = []
        for numchg in numchgs:
            chgsKappas.append(self.finalRes.chgMat[numchg-1, :numchg])
        
        res = edict()
        res.kp1 = kappas[argIdx+1]
        res.numChgs1 = numchgs[argIdx+1]
        res.cpts1 = self.finalRes.chgMat[res.numChgs1-1, :res.numChgs1] 
        res.kp2 = kappas[argmU]
        res.numChgs2 = numchgs[argmU]
        res.cpts2 = self.finalRes.chgMat[res.numChgs2-1, :res.numChgs2] 
        res.chgsKappas = chgsKappas
        
        return res

# %%
def dHdist(set1, set2, n=155):
    set1 = np.array(set1)
    set2 = np.array(set2)
    if len(set2) == 0:
        return 0
    if len(set1) == 0:
        return n
    else:
        absDiff = np.abs(set1.reshape(-1, 1) - set2.reshape(1, -1))
        return absDiff.min(axis=0).max()

# %%
def Hdist(set1, set2, n=155):
    d1 = dHdist(set1, set2, n=n)
    d2 = dHdist(set2, set1, n=n)
    return np.max((d1, d2))

# %%
dHdist([1, 2, 3, 4, 5], [1,2 ,3, 4])
# Out:
# 0

# %%
resDir = Path("../results")
dataDir = Path("../data")

# %%
filname = Path("fMRI_samples.mat")
fMRIs = loadmat(dataDir/filname)["clean_subjects"]

# %% [markdown]
# # 1. Obtain data after HPF

# %%
fs = 0.5 #sampling frequency
fmin = 0.009 # 
fmax = 0.08
hbp = firls(21, np.array([0, 0.009, 0.01, 0.08, 0.09, 0.8]), #0.8
           desired = np.array([0, 0, 1, 1, 0, 0]))

# %%
num = 243
fMRIsHPF = []
for i in range(num):
    cfMRI = fMRIs[0, i]["fMRI"][:90, :]
    # detrend
    cfMRI = detrend(cfMRI)
    chpffMRI = lfilter(hbp, 1, cfMRI)
    fMRIsHPF.append(chpffMRI[:, 25:])

# %% [markdown]
# ### sample plots

# %%
plt.figure(figsize=[10, 5])
plt.subplot(121)
for i in range(90):
    plt.plot(fMRIsHPF[4][i, :])
    
plt.subplot(122)
plt.plot(fMRIsHPF[4][10, :])

# %% [markdown]
# # 2. Obtain seamed data
#
# 1. divide whole data into `k` segments
# 2. the grand truth are different for different data

# %%
def GenRanCpts(ncpt, Lmin, n=155):
    Mdiff = 0
    
    while (Mdiff <=Lmin):
        cpts = np.random.choice(n, size=ncpt, replace=False)
        cpts = np.sort(cpts)
        Mdiff = np.min(np.abs(np.diff(cpts)))
        Mdiff = np.min((cpts[0], Mdiff, n-cpts[-1]))
    return cpts

# %%
#GTs = np.array([
#   [30, 85, 130],
#   [20, 55, 80],
#   [80, 105, 135],
#   [35, 65, 100],
#   [50, 105, 125]
#] * 5)

numchgs = [2, 4, 8, 5, 7, 6, 5, 8, 9, 6]
GTs = [list(GenRanCpts(i, Lmin=10)) for i in numchgs]

GTsAll = []
for GT in GTs:
    numD = len(GT) + 1
    GTsAll = GTsAll + [GT] * numD

# %%
d, n = fMRIsHPF[0].shape

# %%
seamedDatas = []
idxC = 0
for GT in GTs:
    GT = np.array(GT)
    numD = len(GT) + 1
    GT = GT - 1
    GT2 = np.concatenate([GT, [n]]) + 1 
    GT1 = np.concatenate([[0], GT+1])
    cDs = [np.zeros((d, n)) for ii in range(numD)]
    for k in range(numD):
        for l in range(numD):
            cDs[l][:, GT1[k]:GT2[k]] = fMRIsHPF[idxC+(k+l)%numD][:, GT1[k]:GT2[k]]
    idxC += numD
    seamedDatas = seamedDatas + cDs

# %% [markdown]
# ### Verify the seamed data

# %%
#seamedDatas[11][:, 120:] - fMRIsHPF[10][:, 120:]

# %% [markdown]
# ### sample plots

# %%
plt.figure(figsize=[10, 5])
plt.subplot(121)
for i in range(90):
    plt.plot(seamedDatas[4][i, :])
    
plt.subplot(122)
plt.plot(seamedDatas[4][10, :])

# %% [markdown]
# # 3. Detection for kappa

# %%
kappa = 1.53
r = 10
Lmin = 10

results = []
kappas = np.arange(0.68, 4, 0.01)
thdist = 0
for i in tqdm(range(len(seamedDatas))):
    Ymat = seamedDatas[i]
    simuDet = TVDNDetect1(Ymat=Ymat,  saveDir=None, dataType="fMRI", Lmin=Lmin, downRate=4, fct=1, T=2, MaxM=20, 
                        fName="fMRI_HPF", r=r, kappa=1, freq=0.5, lamb=1e-3, showProgress=False, 
                          decimateRate=None, is_detrend=False)
    simuDet()
    GT = GTsAll[i]
    ecpts = simuDet.finalRes.chgMat[len(GT)-1, :len(GT)]
    chdist = Hdist(ecpts, GT)
    thdist += chdist
    
    print(i+1, np.round(thdist/(i+1), 3), Hdist(ecpts, GT), ecpts, GT)
    res = simuDet.TuningKappaNew(kappas)
    results.append(res.chgsKappas)
# Out:
# HBox(children=(IntProgress(value=0, max=70), HTML(value='')))
# 1 61.0 61.0 [ 68. 109.] [13, 48]
# 2 60.0 59.0 [ 42. 107.] [13, 48]
# 3 58.667 56.0 [ 54. 104.] [13, 48]
# 4 47.0 12.0 [ 32.  61.  87. 112.] [33, 73, 97, 109]
# 5 38.8 6.0 [ 33.  67.  95. 115.] [33, 73, 97, 109]
# 6 34.167 11.0 [ 35.  65.  92. 120.] [33, 73, 97, 109]
# 7 31.571 16.0 [ 36.  57.  81. 113.] [33, 73, 97, 109]
# 8 28.625 8.0 [ 31.  68.  93. 117.] [33, 73, 97, 109]
# 9 26.556 10.0 [ 13.  36.  56.  66.  82.  93. 110. 137.] [16, 29, 46, 61, 86, 108, 130, 142]
# 10 25.4 15.0 [ 11.  21.  34.  52.  66.  84. 106. 127.] [16, 29, 46, 61, 86, 108, 130, 142]
# 11 24.455 15.0 [ 13.  29.  40.  51.  65.  83. 106. 127.] [16, 29, 46, 61, 86, 108, 130, 142]
# 12 23.25 10.0 [ 10.  35.  49.  61.  84.  98. 116. 137.] [16, 29, 46, 61, 86, 108, 130, 142]
# 13 22.308 11.0 [ 27.  47.  63.  75.  89. 102. 113. 137.] [16, 29, 46, 61, 86, 108, 130, 142]
# 14 21.5 11.0 [ 23.  41.  59.  72.  85. 106. 121. 145.] [16, 29, 46, 61, 86, 108, 130, 142]
# 15 20.8 11.0 [ 10.  30.  51.  62.  75.  87. 111. 140.] [16, 29, 46, 61, 86, 108, 130, 142]
# 16 20.0 8.0 [ 24.  36.  49.  69.  80. 105. 131. 141.] [16, 29, 46, 61, 86, 108, 130, 142]
# 17 19.353 9.0 [ 11.  22.  39.  58.  77. 101. 115. 135.] [16, 29, 46, 61, 86, 108, 130, 142]
# 18 21.556 59.0 [ 17.  48.  73.  98. 126.] [76, 93, 106, 126, 143]
# 19 22.789 45.0 [ 31.  51.  73.  96. 121.] [76, 93, 106, 126, 143]
# 20 23.8 43.0 [ 33.  58.  82. 106. 133.] [76, 93, 106, 126, 143]
# 21 24.81 45.0 [ 31.  63.  83. 105. 128.] [76, 93, 106, 126, 143]
# 22 25.682 44.0 [ 32.  53.  77. 101. 126.] [76, 93, 106, 126, 143]
# 23 26.478 44.0 [ 32.  60.  88. 109. 132.] [76, 93, 106, 126, 143]
# 24 25.958 14.0 [ 27.  45.  64.  82. 102. 113. 137.] [41, 54, 74, 85, 100, 116, 134]
# 25 25.6 17.0 [ 24.  47.  66.  82.  98. 114. 134.] [41, 54, 74, 85, 100, 116, 134]
# 26 25.692 28.0 [ 13.  28.  40.  71.  84.  98. 124.] [41, 54, 74, 85, 100, 116, 134]
# 27 25.444 19.0 [ 22.  49.  66.  82.  95. 109. 119.] [41, 54, 74, 85, 100, 116, 134]
# 28 24.821 8.0 [ 33.  44.  57.  77.  95. 113. 134.] [41, 54, 74, 85, 100, 116, 134]
# 29 24.586 18.0 [ 23.  50.  63.  80.  98. 111. 133.] [41, 54, 74, 85, 100, 116, 134]
# 30 24.767 30.0 [ 11.  38.  62.  76.  97. 113. 123.] [41, 54, 74, 85, 100, 116, 134]
# 31 24.935 30.0 [ 11.  39.  56.  77.  99. 112. 127.] [41, 54, 74, 85, 100, 116, 134]
# 32 24.438 9.0 [ 17.  44.  70.  88. 108. 135.] [14, 36, 61, 87, 103, 129]
# 33 24.0 10.0 [ 21.  46.  66.  91. 113. 127.] [14, 36, 61, 87, 103, 129]
# 34 23.618 11.0 [ 20.  47.  69.  90. 100. 125.] [14, 36, 61, 87, 103, 129]
# 35 23.114 6.0 [ 18.  41.  67.  84. 105. 126.] [14, 36, 61, 87, 103, 129]
# 36 22.917 16.0 [ 20.  46.  70.  97. 122. 145.] [14, 36, 61, 87, 103, 129]
# 37 22.595 11.0 [ 25.  43.  64.  82. 101. 126.] [14, 36, 61, 87, 103, 129]
# 38 22.316 12.0 [ 24.  50.  75.  90. 101. 124.] [14, 36, 61, 87, 103, 129]
# 39 22.051 12.0 [ 18.  46.  67.  91. 117.] [13, 34, 65, 93, 127]
# 40 21.8 12.0 [ 22.  46.  75.  94. 124.] [13, 34, 65, 93, 127]
# 41 21.61 14.0 [ 27.  53.  77. 102. 132.] [13, 34, 65, 93, 127]
# 42 21.643 23.0 [ 36.  65.  88. 106. 125.] [13, 34, 65, 93, 127]
# 43 21.465 14.0 [ 26.  51.  72.  99. 128.] [13, 34, 65, 93, 127]
# 44 21.432 20.0 [ 33.  60.  91. 115. 136.] [13, 34, 65, 93, 127]
# 45 21.156 9.0 [ 17.  42.  61.  71.  94. 115. 125. 143.] [26, 43, 60, 77, 93, 112, 127, 141]
# 46 20.978 13.0 [ 20.  40.  50.  73.  86.  99. 125. 139.] [26, 43, 60, 77, 93, 112, 127, 141]
# 47 20.894 17.0 [ 11.  29.  48.  65.  83.  95. 113. 124.] [26, 43, 60, 77, 93, 112, 127, 141]
# 48 20.729 13.0 [ 13.  35.  53.  69.  89. 110. 132. 144.] [26, 43, 60, 77, 93, 112, 127, 141]
# 49 20.449 7.0 [ 21.  41.  53.  75.  89. 110. 121. 139.] [26, 43, 60, 77, 93, 112, 127, 141]
# 50 20.26 11.0 [ 15.  45.  56.  66.  81. 101. 123. 133.] [26, 43, 60, 77, 93, 112, 127, 141]
# 51 20.059 10.0 [ 16.  40.  61.  83. 103. 113. 132. 143.] [26, 43, 60, 77, 93, 112, 127, 141]
# 52 19.808 7.0 [ 29.  47.  61.  77. 100. 117. 132. 143.] [26, 43, 60, 77, 93, 112, 127, 141]
# 53 19.679 13.0 [ 13.  23.  48.  58.  79.  94. 110. 131.] [26, 43, 60, 77, 93, 112, 127, 141]
# 54 19.481 9.0 [ 23.  34.  56.  70.  81.  97. 108. 128. 144.] [17, 29, 43, 59, 71, 85, 105, 123, 137]
# 55 19.291 9.0 [ 20.  37.  54.  64.  76.  86.  96. 110. 130.] [17, 29, 43, 59, 71, 85, 105, 123, 137]
# 56 19.071 7.0 [ 10.  22.  36.  58.  76.  90. 101. 118. 130.] [17, 29, 43, 59, 71, 85, 105, 123, 137]
# 57 18.895 9.0 [ 11.  30.  40.  57.  75.  90. 107. 132. 144.] [17, 29, 43, 59, 71, 85, 105, 123, 137]
# 58 18.724 9.0 [ 11.  21.  34.  58.  68.  86. 105. 121. 144.] [17, 29, 43, 59, 71, 85, 105, 123, 137]
# 59 18.508 6.0 [ 13.  32.  44.  56.  76.  91. 107. 129. 140.] [17, 29, 43, 59, 71, 85, 105, 123, 137]
# 60 18.35 9.0 [ 15.  28.  42.  63.  75.  85. 114. 133. 145.] [17, 29, 43, 59, 71, 85, 105, 123, 137]
# 61 18.148 6.0 [ 23.  40.  53.  63.  75.  88. 105. 119. 142.] [17, 29, 43, 59, 71, 85, 105, 123, 137]
# 62 18.0 9.0 [ 26.  46.  60.  79.  90. 105. 120. 130. 144.] [17, 29, 43, 59, 71, 85, 105, 123, 137]
# 63 17.825 7.0 [ 24.  34.  48.  58.  68.  88. 102. 121. 135.] [17, 29, 43, 59, 71, 85, 105, 123, 137]
# 64 17.781 15.0 [ 12.  36.  54.  77. 103. 127.] [27, 44, 56, 73, 117, 129]
# 65 17.677 11.0 [ 35.  48.  69.  84. 110. 135.] [27, 44, 56, 73, 117, 129]
# 66 17.576 11.0 [ 29.  46.  64.  84. 113. 130.] [27, 44, 56, 73, 117, 129]
# 67 17.537 15.0 [ 27.  49.  71.  83. 102. 125.] [27, 44, 56, 73, 117, 129]
# 68 17.529 17.0 [ 28.  38.  61.  78. 100. 122.] [27, 44, 56, 73, 117, 129]
# 69 17.507 16.0 [ 17.  42.  60.  80. 101. 126.] [27, 44, 56, 73, 117, 129]
# 70 17.571 22.0 [ 30.  47.  71.  95. 118. 131.] [27, 44, 56, 73, 117, 129]

# %%
hdists = []
for k, ress in enumerate(results):
    GT = GTsAll[k]
    hdist = [Hdist(res, GT)for res in ress]
    hdists.append(hdist)

# %%
hdists = np.array(hdists)

# %%
mhdist = hdists.mean(axis=0)

# %%
plt.xlabel("kappa")
plt.ylabel("h distance")
plt.plot(kappas, mhdist)

# %%
optKappa = kappas[np.argmin(mhdist)];optKappa
# Out:
# 1.3800000000000008

# %% [markdown]
# # 4. Detection on optimal kappa

# %% [markdown]
# ## Data 9

# %%
fMRI9 = fMRIs[0, 9]["fMRI"][:90, :]
fMRI9 = detrend(fMRI9)
hpffMRI = lfilter(hbp, 1, fMRI9)
hpffMRI = hpffMRI[:, 25:]

# %%
r = 10 
Lmin = 10

# %%
fMRIDet = TVDNDetect1(Ymat=hpffMRI,  saveDir=None, dataType="fMRI", Lmin=Lmin, downRate=4, fct=1, T=2, MaxM=20, 
                        fName="fMRI_HPF", r=r, kappa=optKappa, freq=0.5, lamb=1e-4, showProgress=True, 
                          decimateRate=None, is_detrend=False)
fMRIDet()
# Out:
# The parameters for detection are:
# {'Lmin': 10,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 4,
#  'fName': 'fMRI_HPF',
#  'fct': 1,
#  'freq': 0.5,
#  'is_detrend': False,
#  'kappa': 1.3800000000000008,
#  'lamb': 0.0001,
#  'nbasis': 10,
#  'r': 10}
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=155, style=ProgressStyle(descriptio…

# %%
fMRIDet.PlotEcpts()

# %%
fMRIDet.PlotEigenCurve()

# %%
print(fMRIDet)
# Out:
# +-------------+-------------------------------+--------------------+------+
# | Num of CPTs |         Estiamted CPTs        |        MSE         | Rank |
# +-------------+-------------------------------+--------------------+------+
# |      7      | [ 21  45  59  72  90 106 126] | 2.9315441833900344 |  10  |
# +-------------+-------------------------------+--------------------+------+

# %% [markdown]
# ## Data 100

# %%
fMRI100 = fMRIs[0, 100]["fMRI"][:90, :]
fMRI100 = detrend(fMRI100)
hpffMRI = lfilter(hbp, 1, fMRI100)
hpffMRI = hpffMRI[:, 25:]

# %%
r = 10
Lmin = 10

# %%
fMRIDet = TVDNDetect1(Ymat=hpffMRI,  saveDir=None, dataType="fMRI", Lmin=Lmin, downRate=4, fct=1, T=2, MaxM=10, 
                        fName="fMRI_HPF", r=r, kappa=optKappa, freq=0.5, lamb=1e-4, showProgress=True, 
                          decimateRate=None, is_detrend=False)
fMRIDet()
# Out:
# The parameters for detection are:
# {'Lmin': 10,
#  'MaxM': 10,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 4,
#  'fName': 'fMRI_HPF',
#  'fct': 1,
#  'freq': 0.5,
#  'is_detrend': False,
#  'kappa': 1.3800000000000008,
#  'lamb': 0.0001,
#  'nbasis': 10,
#  'r': 10}
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=155, style=ProgressStyle(descriptio…

# %%
fMRIDet.PlotEcpts()

# %%
fMRIDet.PlotEigenCurve()

# %%
print(fMRIDet)
# Out:
# +-------------+-----------------------------------+--------------------+------+
# | Num of CPTs |           Estiamted CPTs          |        MSE         | Rank |
# +-------------+-----------------------------------+--------------------+------+
# |      8      | [ 20  36  52  68  86 102 117 132] | 1.5311617262690593 |  10  |
# +-------------+-----------------------------------+--------------------+------+

# %% [markdown]
# ## Data 150

# %%
fMRI150 = fMRIs[0, 150]["fMRI"][:90, :]
fMRI150 = detrend(fMRI150)
hpffMRI = lfilter(hbp, 1, fMRI150)
hpffMRI = hpffMRI[:, 25:]

# %%
r = 10
Lmin = 10

# %%
fMRIDet = TVDNDetect1(Ymat=hpffMRI,  saveDir=None, dataType="fMRI", Lmin=Lmin, downRate=4, fct=1, T=2, MaxM=10, 
                        fName="fMRI_HPF", r=r, kappa=optKappa, freq=0.5, lamb=1e-4, showProgress=True, 
                          decimateRate=None, is_detrend=False)
fMRIDet()
# Out:
# The parameters for detection are:
# {'Lmin': 10,
#  'MaxM': 10,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 4,
#  'fName': 'fMRI_HPF',
#  'fct': 1,
#  'freq': 0.5,
#  'is_detrend': False,
#  'kappa': 1.3800000000000008,
#  'lamb': 0.0001,
#  'nbasis': 10,
#  'r': 10}
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=155, style=ProgressStyle(descriptio…

# %%
fMRIDet.PlotEcpts()

# %%
fMRIDet.PlotEigenCurve()

# %%
print(fMRIDet)
# Out:
# +-------------+-------------------------------+-------------------+------+
# | Num of CPTs |         Estiamted CPTs        |        MSE        | Rank |
# +-------------+-------------------------------+-------------------+------+
# |      7      | [ 22  41  64  78 100 115 135] | 2.209243202619834 |  10  |
# +-------------+-------------------------------+-------------------+------+

# %% [markdown]
# ## Data 200

# %%
fMRI200 = fMRIs[0, 200]["fMRI"][:90, :]
fMRI200 = detrend(fMRI200)
hpffMRI = lfilter(hbp, 1, fMRI200)
hpffMRI = hpffMRI[:, 25:]

# %%
r = 10
Lmin = 10

# %%
fMRIDet = TVDNDetect1(Ymat=hpffMRI,  saveDir=None, dataType="fMRI", Lmin=Lmin, downRate=4, fct=1, T=2, MaxM=10, 
                        fName="fMRI_HPF", r=r, kappa=optKappa, freq=0.5, lamb=1e-4, showProgress=True, 
                          decimateRate=None, is_detrend=False)
fMRIDet()
# Out:
# The parameters for detection are:
# {'Lmin': 10,
#  'MaxM': 10,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 4,
#  'fName': 'fMRI_HPF',
#  'fct': 1,
#  'freq': 0.5,
#  'is_detrend': False,
#  'kappa': 1.3800000000000008,
#  'lamb': 0.0001,
#  'nbasis': 10,
#  'r': 10}
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=155, style=ProgressStyle(descriptio…

# %%
fMRIDet.PlotEcpts()

# %%
fMRIDet.PlotEigenCurve()

# %%
print(fMRIDet)
# Out:
# +-------------+-----------------------------------+--------------------+------+
# | Num of CPTs |           Estiamted CPTs          |        MSE         | Rank |
# +-------------+-----------------------------------+--------------------+------+
# |      8      | [ 25  48  68  82  92 108 125 142] | 1.3109184875805602 |  10  |
# +-------------+-----------------------------------+--------------------+------+

# %% [markdown]
# ## Results on seamed data

# %% [markdown]
# ### Data 10

# %%
r = 10
Lmin = 10
idx = 10

# %%
seamedfMRIDet = TVDNDetect1(Ymat=seamedDatas[idx],  saveDir=None, dataType="fMRI", Lmin=Lmin, downRate=4, fct=1, T=2, MaxM=10, 
                        fName="fMRI_HPF", r=r, kappa=optKappa, freq=0.5, lamb=1e-4, showProgress=True, 
                          decimateRate=None, is_detrend=False)
seamedfMRIDet()
# Out:
# The parameters for detection are:
# {'Lmin': 10,
#  'MaxM': 10,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 4,
#  'fName': 'fMRI_HPF',
#  'fct': 1,
#  'freq': 0.5,
#  'is_detrend': False,
#  'kappa': 1.3800000000000008,
#  'lamb': 0.0001,
#  'nbasis': 10,
#  'r': 10}
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=155, style=ProgressStyle(descriptio…

# %%
seamedfMRIDet.PlotEigenCurve()

# %%
print(seamedfMRIDet)
# Out:
# +-------------+---------------------------------------+--------------------+------+
# | Num of CPTs |             Estiamted CPTs            |        MSE         | Rank |
# +-------------+---------------------------------------+--------------------+------+
# |      9      | [ 21  33  47  63  82  98 110 126 141] | 1.6432730069873736 |  10  |
# +-------------+---------------------------------------+--------------------+------+

# %% [markdown]
# #### truth

# %%
GTsAll[idx]
# Out:
# [16, 29, 46, 61, 86, 108, 130, 142]

# %% [markdown]
# #### detected vs truth

# %%
seamedfMRIDet.PlotEcpts()
seamedfMRIDet.ecpts = GTsAll[idx]
seamedfMRIDet.PlotEcpts()

# %% [markdown]
# ### Data 20

# %%
r = 10
Lmin = 10
idx = 20

# %%
seamedfMRIDet = TVDNDetect1(Ymat=seamedDatas[idx],  saveDir=None, dataType="fMRI", Lmin=Lmin, downRate=4, fct=1, T=2, MaxM=10, 
                        fName="fMRI_HPF", r=r, kappa=optKappa, freq=0.5, lamb=1e-4, showProgress=True, 
                          decimateRate=None, is_detrend=False)
seamedfMRIDet()
# Out:
# The parameters for detection are:
# {'Lmin': 10,
#  'MaxM': 10,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 4,
#  'fName': 'fMRI_HPF',
#  'fct': 1,
#  'freq': 0.5,
#  'is_detrend': False,
#  'kappa': 1.3800000000000008,
#  'lamb': 0.0001,
#  'nbasis': 10,
#  'r': 10}
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=155, style=ProgressStyle(descriptio…

# %%
seamedfMRIDet.PlotEigenCurve()

# %%
print(seamedfMRIDet)
# Out:
# +-------------+-------------------------------+-------------------+------+
# | Num of CPTs |         Estiamted CPTs        |        MSE        | Rank |
# +-------------+-------------------------------+-------------------+------+
# |      7      | [ 26  43  59  77  96 114 130] | 1.388489159030397 |  10  |
# +-------------+-------------------------------+-------------------+------+

# %% [markdown]
# #### truth

# %%
GTsAll[idx]
# Out:
# [76, 93, 106, 126, 143]

# %% [markdown]
# #### detected vs truth

# %%
seamedfMRIDet.PlotEcpts()
seamedfMRIDet.ecpts = GTsAll[idx]
seamedfMRIDet.PlotEcpts()

# %% [markdown]
# ### Data 50

# %%
r = 10
Lmin = 10
idx = 50

# %%
seamedfMRIDet = TVDNDetect1(Ymat=seamedDatas[idx],  saveDir=None, dataType="fMRI", Lmin=Lmin, downRate=4, fct=1, T=2, MaxM=10, 
                        fName="fMRI_HPF", r=r, kappa=optKappa, freq=0.5, lamb=1e-4, showProgress=True, 
                          decimateRate=None, is_detrend=False)
seamedfMRIDet()
# Out:
# The parameters for detection are:
# {'Lmin': 10,
#  'MaxM': 10,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 4,
#  'fName': 'fMRI_HPF',
#  'fct': 1,
#  'freq': 0.5,
#  'is_detrend': False,
#  'kappa': 1.3800000000000008,
#  'lamb': 0.0001,
#  'nbasis': 10,
#  'r': 10}
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=155, style=ProgressStyle(descriptio…

# %%
seamedfMRIDet.PlotEigenCurve()

# %%
print(seamedfMRIDet)
# Out:
# +-------------+-----------------------------------+--------------------+------+
# | Num of CPTs |           Estiamted CPTs          |        MSE         | Rank |
# +-------------+-----------------------------------+--------------------+------+
# |      8      | [ 22  40  57  75  89 103 117 137] | 1.4777674771830285 |  10  |
# +-------------+-----------------------------------+--------------------+------+

# %% [markdown]
# #### truth

# %%
GTsAll[idx]
# Out:
# [26, 43, 60, 77, 93, 112, 127, 141]

# %% [markdown]
# #### detected vs truth

# %%
seamedfMRIDet.PlotEcpts()
seamedfMRIDet.ecpts = GTsAll[idx]
seamedfMRIDet.PlotEcpts()
