# %%
import sys
sys.path.append("/home/huaqingj/MyResearch/TVDN")

# %%
from pyTVDN import TVDNDetect, TVDNRankTuning
from pathlib import Path
from scipy.io import loadmat
from scipy.signal import detrend
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pyTVDN.tmpUtils import *
# %matplotlib inline

# %%
from pprint import pprint
import pickle
from easydict import EasyDict as edict
import warnings
from pyTVDN.TVDNutils import *
from pyTVDN.utils import in_notebook
if in_notebook():
    from tqdm import tqdm_notebook as tqdm
else:
    from tqdm import tqdm

class TVDNDetect1(TVDNDetect):
    def SmoothEst(self):
        if self.nYmat is None:
            self._Preprocess()
        d, n = self.nYmat.shape
        acTime = n / self.paras.freq
        self.ptime = np.linspace(0, acTime, n)
        self.time = np.linspace(0, self.paras.T, n)
        divNum = 100
        if self.smoothType == "bspline":
            self.dXmat = np.zeros((d, n))
            self.Xmat = np.zeros((d, n))
            if n%divNum == 0:
                numLoop = int(n/divNum)
            else:
                numLoop = int(n/divNum) + 1
            for i in range(numLoop):
                if (i+1)*divNum <= n:
                    low = i*divNum
                    up = (i+1)*divNum
                else:
                    low = i*divNum
                    up = n
                self.dXmat[:, low:up], self.Xmat[:, low:up] = GetBsplineEst(self.nYmat[:, low:up], self.time[low:up], 
                                                                            lamb=self.paras.lamb)
        elif self.smoothType == "fourier":
            self.dXmat, self.Xmat = GetFourierEst(self.nYmat, self.time, nbasis=self.paras.nbasis)

# %%
resDir = Path("../results")
dataDir = Path("../data/newMEGdata")

# %%
datFil = list(dataDir.glob("*03*20.mat"))[0]
datFil
# Out:
# PosixPath('../data/newMEGdata/lcmv_result_R2868E_03-st_wo_filtering_20.mat')

# %%
gtF = list(dataDir.glob("*_03_st.txt"))[0]
gtSt03 = time2pts(txt2Time(gtF), timeLims.st03)

# %%
txt2Time(gtF)
# Out:
# [22.2866666667,
#  32.8766666667,
#  42.4933333333,
#  53.9166666667,
#  68.9333333333,
#  78.1666666667]

# %%
timeLims.st03
# Out:
# [20, 80]

# %%
gtSt03.cpts
# Out:
# array([ 274, 1545, 2699, 4070, 5871, 6980])

# %%
np.diff(gtSt03.cpts)
# Out:
# array([1271, 1154, 1371, 1801, 1109])

# %%
from scipy.signal import lfilter, firls, decimate

# %%
q = 10

# %% [markdown]
# ## Plot the data

# %%
MEG = loadmat(datFil)

# %%
data = MEG["DK_timecourse"]

# %% [markdown]
# The time course is 60 seconds, so the frequency is 1200 Hz

# %%
d, n = data.shape

# %% [markdown]
# ###  Data preprocessing

# %%
dataN = decimate(data, q=q)
dataN = detrend(dataN)

# %% [markdown]
# ### HPF

# %%
fs = 120 #sampling frequency
fmin = 2 # 2Hz - 45Hz signal range, filter for this with hbp
fmax = 45
hbp = firls(101, np.array([0, 0.2*fmin, 0.9*fmin, fmax-2, fmax+5, 60])*2/fs,
           desired = np.array([0, 0, 1, 1, 0, 0])) #for detrending, a bandpass

# %%
dataHPF = lfilter(hbp, 1, dataN)

# %% [markdown]
# ## Detection on data without HPF

# %%
paras = edict()
paras.Lmin = 200
paras.wh = 10 
paras.MaxM = 20
paras.fct = 0.5
paras.r = 12 
paras.freq = 120
paras.lamb = 1e-4
paras.T = 2
paras.is_detrend = False
paras.decimateRate = None
paras.kappa = 1
paras.downRate = 20

# %%
detRaw = TVDNDetect1(Ymat=dataN, dataType="MEG", 
                     saveDir=None, 
                     fName="MEG1",
                     showProgress=True, 
                     MaxM=paras.MaxM,
                     Lmin=paras.Lmin, 
                     lamb=paras.lamb, 
                     kappa=paras.kappa, 
                     freq=paras.freq,
                     r=paras.r,
                     T=paras.T,
                     is_detrend=paras.is_detrend,
                     decimateRate=paras.decimateRate, 
                     downRate=paras.downRate)
# Out:
# The parameters for detection are:
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'MEG1',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 1,
#  'lamb': 0.0001,
#  'nbasis': 10,
#  'r': 12}

# %%
detRaw.Screening(wh=paras.wh)
# Out:
# HBox(children=(IntProgress(value=0, description='Screening', max=7200, style=ProgressStyle(description_width='…

# %%
detRaw()
# Out:
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=382, style=ProgressStyle(descriptio…

# %%
kappas = np.linspace(1, 4, 1000)
detRaw.TuningKappa(kappas)
# Out:
# HBox(children=(IntProgress(value=0, max=21), HTML(value='')))

# %%
detRaw.UpdateEcpts()
print(detRaw)
detRaw.PlotEcpts(GT=gtSt03.cpts)
# Out:
# +-------------+----------------+--------------------+------+
# | Num of CPTs | Estiamted CPTs |        MSE         | Rank |
# +-------------+----------------+--------------------+------+
# |      0      |       []       | 1.0752489887345378 |  12  |
# +-------------+----------------+--------------------+------+

# %%
detRaw.UpdateEcpts(10)
print(detRaw)
detRaw.PlotEcpts(GT=gtSt03.cpts)
# Out:
# +-------------+---------------------------------------------------------------+--------------------+------+
# | Num of CPTs |                         Estiamted CPTs                        |        MSE         | Rank |
# +-------------+---------------------------------------------------------------+--------------------+------+
# |      10     | [ 667. 2035. 2292. 3474. 3700. 4551. 4848. 5048. 5283. 6161.] | 1.2449533452614265 |  12  |
# +-------------+---------------------------------------------------------------+--------------------+------+

# %% [markdown]
# ## Detection after HPF

# %% [markdown]
# **Good**
#
# wh = 10

# %%
dataHPF.shape
# Out:
# (68, 7200)

# %%
detHPF = TVDNDetect1(Ymat=dataHPF, dataType="MEG", 
                     saveDir=None, 
                     fName="HPF1",
                     showProgress=True, 
                     MaxM=paras.MaxM,
                     Lmin=paras.Lmin, 
                     lamb=paras.lamb, 
                     kappa=paras.kappa, 
                     freq=paras.freq,
                     r=paras.r,
                     T=paras.T,
                     is_detrend=paras.is_detrend,
                     decimateRate=paras.decimateRate, 
                     downRate=paras.downRate)
# Out:
# The parameters for detection are:
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'HPF1',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 1,
#  'lamb': 0.0001,
#  'nbasis': 10,
#  'r': 12}

# %%
detHPF.Screening(wh=paras.wh)#
# Out:
# HBox(children=(IntProgress(value=0, description='Screening', max=7200, style=ProgressStyle(description_width='…

# %%
detHPF()
# Out:
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=299, style=ProgressStyle(descriptio…

# %%
kappas = np.linspace(1, 4, 1000)
detHPF.TuningKappa(kappas)
# Out:
# HBox(children=(IntProgress(value=0, max=21), HTML(value='')))

# %%
detHPF.UpdateEcpts()
print(detHPF)
detHPF.PlotEcpts(GT=gtSt03.cpts)
# Out:
# +-------------+----------------+--------------------+------+
# | Num of CPTs | Estiamted CPTs |        MSE         | Rank |
# +-------------+----------------+--------------------+------+
# |      0      |       []       | 334025.09630430385 |  12  |
# +-------------+----------------+--------------------+------+

# %%
detHPF.UpdateEcpts(6)
print(detHPF)
detHPF.PlotEcpts(GT=gtSt03.cpts)
# Out:
# +-------------+---------------------------------------+--------------------+------+
# | Num of CPTs |             Estiamted CPTs            |        MSE         | Rank |
# +-------------+---------------------------------------+--------------------+------+
# |      6      | [ 213.  777. 1938. 3477. 4900. 6200.] | 5107077428580740.0 |  12  |
# +-------------+---------------------------------------+--------------------+------+
