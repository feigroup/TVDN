# %%
import sys
sys.path.append("/home/huaqingj/MyResearch/TVDN")

# %%
from pyTVDN import TVDNDetect, TVDNRankTuning
from pathlib import Path
from scipy.io import loadmat
from scipy.signal import detrend
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pyTVDN.tmpUtils import *
from scipy.signal import lfilter, firls, decimate
# %matplotlib inline
plt.style.use('ggplot')

# %%
from pprint import pprint
import pickle
from easydict import EasyDict as edict
import warnings
from pyTVDN.TVDNutils import *
from pyTVDN.utils import in_notebook
if in_notebook():
    from tqdm import tqdm_notebook as tqdm
else:
    from tqdm import tqdm

class TVDNDetect1(TVDNDetect):
    def SmoothEst(self):
        if self.nYmat is None:
            self._Preprocess()
        d, n = self.nYmat.shape
        acTime = n / self.paras.freq
        self.ptime = np.linspace(0, acTime, n)
        self.time = np.linspace(0, self.paras.T, n)
        divNum = 100
        if self.smoothType == "bspline":
            self.dXmat = np.zeros((d, n))
            self.Xmat = np.zeros((d, n))
            if n%divNum == 0:
                numLoop = int(n/divNum)
            else:
                numLoop = int(n/divNum) + 1
            for i in range(numLoop):
                if (i+1)*divNum <= n:
                    low = i*divNum
                    up = (i+1)*divNum
                else:
                    low = i*divNum
                    up = n
                self.dXmat[:, low:up], self.Xmat[:, low:up] = GetBsplineEst(self.nYmat[:, low:up], self.time[low:up], 
                                                                            lamb=self.paras.lamb)
        elif self.smoothType == "fourier":
            self.dXmat, self.Xmat = GetFourierEst(self.nYmat, self.time, nbasis=self.paras.nbasis)

# %%
resDir = Path("../results")
dataDir = Path("../data/MEG-resting-state")

# %%
datFil = list(dataDir.glob("*8002*min.mat"))[0]
print(datFil)

MEG = loadmat(datFil)
data = MEG["DK_timecourse"]
data.shape
# Out:
# ../data/MEG-resting-state/lcmv_result_8002-101_wo_filtering_min.mat
# (68, 35999)

# %% [markdown]
# The time course is 60 seconds, so the frequency is 600 Hz

# %% [markdown]
# ###  Data preprocessing

# %%
q = 5
dataN = decimate(data, q=q)
dataN = detrend(dataN)

# %%
d, n = dataN.shape
for i in range(d):
    plt.plot(dataN[i, :])

# %% [markdown]
# ### Tuning kappa

# %%
paras = edict()
paras.Lmin = 200
paras.wh = 10
paras.MaxM = 20
paras.fct = 0.5
paras.r = None
paras.freq = 120
paras.lamb = 1e-2
paras.T = 2
paras.is_detrend = False
paras.decimateRate = None
paras.kappa = 2.77
paras.downRate = 20

detObjs = []
for i in range(5):
    dataPart = data[:, i::5]
    dataPart = detrend(dataPart)
    detPart = TVDNDetect(Ymat=dataPart, dataType="MEG", 
                         saveDir=None, #"MEGst02", 
                         fName="MEG1",
                         showProgress=True, 
                         MaxM=paras.MaxM,
                         Lmin=paras.Lmin, 
                         lamb=paras.lamb, 
                         kappa=paras.kappa, 
                         freq=paras.freq,
                         r=paras.r,
                         T=paras.T,
                         is_detrend=paras.is_detrend,
                         decimateRate=paras.decimateRate, 
                         downRate=paras.downRate)
    detPart.Screening(wh=paras.wh)
    detPart()
    kappas = np.arange(1, 4, 0.001)
    detPart.TuningKappa(kappas)
    detObjs.append(detPart)
# Out:
# The parameters for detection are:
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'MEG1',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 2.77,
#  'lamb': 0.01,
#  'nbasis': 10,
#  'r': None}
# HBox(children=(IntProgress(value=0, description='Screening', max=7200, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=215, style=ProgressStyle(descriptio…
# HBox(children=(IntProgress(value=0, max=21), HTML(value='')))
# The parameters for detection are:
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'MEG1',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 2.77,
#  'lamb': 0.01,
#  'nbasis': 10,
#  'r': None}
# HBox(children=(IntProgress(value=0, description='Screening', max=7200, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=230, style=ProgressStyle(descriptio…
# HBox(children=(IntProgress(value=0, max=21), HTML(value='')))
# The parameters for detection are:
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'MEG1',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 2.77,
#  'lamb': 0.01,
#  'nbasis': 10,
#  'r': None}
# HBox(children=(IntProgress(value=0, description='Screening', max=7200, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=213, style=ProgressStyle(descriptio…
# HBox(children=(IntProgress(value=0, max=21), HTML(value='')))
# The parameters for detection are:
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'MEG1',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 2.77,
#  'lamb': 0.01,
#  'nbasis': 10,
#  'r': None}
# HBox(children=(IntProgress(value=0, description='Screening', max=7200, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=215, style=ProgressStyle(descriptio…
# HBox(children=(IntProgress(value=0, max=21), HTML(value='')))
# The parameters for detection are:
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'MEG1',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 2.77,
#  'lamb': 0.01,
#  'nbasis': 10,
#  'r': None}
# HBox(children=(IntProgress(value=0, description='Screening', max=7199, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=220, style=ProgressStyle(descriptio…
# HBox(children=(IntProgress(value=0, max=21), HTML(value='')))

# %%
numchgss = []
for i in range(5):
    numchgs = detObjs[i].numchgs
    numchgss.append(numchgs)
    
numchgssArr = np.array(numchgss)
varsAll = np.var(numchgssArr, axis=0)

kpidxs = ((kappas >= 2.9).astype(np.int) + (kappas<=3.1)) == 2
subVarsAll = varsAll[kpidxs]
subKappas = kappas[kpidxs]

plt.subplot(211)
plt.plot(subKappas, subVarsAll)
plt.subplot(212)
plt.plot(kappas, varsAll)

# %%
optKaIdx = np.argmin(subVarsAll)
optKappa = subKappas[optKaIdx]
print(optKappa)
# Out:
# 3.004999999999779

# %% [markdown]
# ## Detection on data with screening and no HPF

# %%
paras = edict()
paras.Lmin = 200
paras.wh = 10
paras.MaxM = 20
paras.fct = 0.5
paras.r = None
paras.freq = 120
paras.lamb = 1e-2
paras.T = 2
paras.is_detrend = False
paras.decimateRate = None
paras.kappa = optKappa
paras.downRate = 20

# %%
detRaw = TVDNDetect(Ymat=dataN, dataType="MEG", 
                     saveDir=None, #"MEGst02", 
                     fName="MEG1",
                     showProgress=True, 
                     MaxM=paras.MaxM,
                     Lmin=paras.Lmin, 
                     lamb=paras.lamb, 
                     kappa=paras.kappa, 
                     freq=paras.freq,
                     r=paras.r,
                     T=paras.T,
                     is_detrend=paras.is_detrend,
                     decimateRate=paras.decimateRate, 
                     downRate=paras.downRate)
# Out:
# The parameters for detection are:
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'MEG1',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 3.004999999999779,
#  'lamb': 0.01,
#  'nbasis': 10,
#  'r': None}

# %%
detRaw.Screening(wh=paras.wh)
detRaw()
# Out:
# HBox(children=(IntProgress(value=0, description='Screening', max=7200, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=225, style=ProgressStyle(descriptio…

# %% [markdown]
# Sequences after B-spline

# %%
for i in range(detRaw.Xmat.shape[0]):
    plt.plot(detRaw.Xmat[i, :])

# %%
print(detRaw)
detRaw.PlotEcpts()
detRaw.PlotEigenCurve()
# Out:
# +-------------+--------------------------------------+-------------------+------+
# | Num of CPTs |            Estiamted CPTs            |        MSE        | Rank |
# +-------------+--------------------------------------+-------------------+------+
# |      7      | [ 883 1588 2544 3284 4835 6457 6844] | 6.078730721441804 |  5   |
# +-------------+--------------------------------------+-------------------+------+

# %%
print(np.diff(detRaw.ecpts))
# Out:
# [ 705  956  740 1551 1622  387]

# %% [markdown]
# ### Save results

# %%
def obtainwU(DetObj):
    eigVecs = DetObj.midRes.eigVecs[:, :DetObj.paras.r]
    kpidxs = np.concatenate([[0], DetObj.ecpts]).astype(np.int)
    eigVals = DetObj.RecResCur.LamMs[:, kpidxs]
    wU = eigVecs.dot(eigVals)
    return wU

def minmax(x):
    num = x - np.min(x)
    den = np.max(x) - np.min(x)
    return num/den

# %%
wUst = obtainwU(detRaw)
wUst = np.transpose(wUst)
abswUst = np.abs(wUst)
# save to npy file
with open("MEGRS8002_Screening_abswU_full.npy", "wb") as f:
    np.save(f, abswUst)
with open("MEGRS8002_Screening_wU_full.npy", "wb") as f:
    np.save(f, wUst)

abswUstMM = np.zeros_like(abswUst)
for i, col in enumerate(abswUst):
    lh = minmax(col[:34])
    rh = minmax(col[34:])
    abswUstMM[i, :34] = lh
    abswUstMM[i, 34:] = rh

# %%
import pandas as pd

fcR = pd.read_csv('../data/brain_plot_meg/DK_dic68.csv').set_index('Unnamed: 0')
rowNames = list(fcR.index)
colNames = np.array(fcR.columns)

fcRarr = np.array(fcR)

# minmax 
fcRarrMM = np.zeros_like(fcRarr)
for i, fcRar in enumerate(fcRarr):
    lh = minmax(fcRar[:34])
    rh = minmax(fcRar[34:])
    fcRarrMM[i, :34] = lh
    fcRarrMM[i, 34:] = rh

# %%
from collections import OrderedDict as odict
csvD = odict()
for i, name in enumerate(colNames):
    csvD[name] = abswUstMM[:, i]

csvD = pd.DataFrame(csvD)
csvD.to_csv("wU_Screening_minmax_RS8002.csv")

# %%
import scipy.stats as ss
from collections import defaultdict as ddict
corrs = ddict(list)
for absU in abswUstMM:
    for j, name in enumerate(rowNames):
        corrs[name].append(ss.pearsonr(fcRarrMM[j, :], absU)[0])
        #corrs[name].append(ss.spearmanr(fcRarrMM[j, :], absU)[0])
    
corrsDF = pd.DataFrame(corrs)
corrsDF.to_csv("corrs_Screenig_RS8002.csv")
corrsDF
# Out:
#     Default  Dorsal_Attention  Frontoparietal    Limbic  Somatomotor  \
# 0 -0.424302          0.141685       -0.024519 -0.184613     0.150357
# 1 -0.202634          0.323160       -0.092882  0.191216     0.021395
# 2 -0.126798          0.448177        0.085255 -0.000353    -0.019227
# 3 -0.163478         -0.030599        0.187834  0.036022    -0.163543
# 4 -0.048324          0.264679       -0.001859  0.188262     0.108889
# 5 -0.124126          0.435498       -0.123929  0.072777     0.056977
# 6 -0.178412          0.119346       -0.187242  0.282753    -0.071196
# 7  0.180763          0.023436        0.620514  0.011679    -0.238053
#
#    Ventral_Attention    Visual
# 0          -0.049572  0.307775
# 1           0.034702 -0.149707
# 2           0.051685 -0.158227
# 3          -0.148511  0.252823
# 4           0.065736 -0.337477
# 5          -0.030749 -0.125641
# 6          -0.146742  0.114260
# 7           0.038881 -0.286982
