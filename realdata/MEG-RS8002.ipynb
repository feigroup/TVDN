# %%
import sys
sys.path.append("/home/huaqingj/MyResearch/TVDN")

# %%
from pyTVDN import TVDNDetect, TVDNRankTuning
from pathlib import Path
from scipy.io import loadmat
from scipy.signal import detrend
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pyTVDN.tmpUtils import *
from scipy.signal import lfilter, firls, decimate
# %matplotlib inline
plt.style.use('ggplot')

# %%
from pprint import pprint
import pickle
from easydict import EasyDict as edict
import warnings
from pyTVDN.TVDNutils import *
from pyTVDN.utils import in_notebook
if in_notebook():
    from tqdm import tqdm_notebook as tqdm
else:
    from tqdm import tqdm

class TVDNDetect1(TVDNDetect):
    def SmoothEst(self):
        if self.nYmat is None:
            self._Preprocess()
        d, n = self.nYmat.shape
        acTime = n / self.paras.freq
        self.ptime = np.linspace(0, acTime, n)
        self.time = np.linspace(0, self.paras.T, n)
        divNum = 100
        if self.smoothType == "bspline":
            self.dXmat = np.zeros((d, n))
            self.Xmat = np.zeros((d, n))
            if n%divNum == 0:
                numLoop = int(n/divNum)
            else:
                numLoop = int(n/divNum) + 1
            for i in range(numLoop):
                if (i+1)*divNum <= n:
                    low = i*divNum
                    up = (i+1)*divNum
                else:
                    low = i*divNum
                    up = n
                self.dXmat[:, low:up], self.Xmat[:, low:up] = GetBsplineEst(self.nYmat[:, low:up], self.time[low:up], 
                                                                            lamb=self.paras.lamb)
        elif self.smoothType == "fourier":
            self.dXmat, self.Xmat = GetFourierEst(self.nYmat, self.time, nbasis=self.paras.nbasis)

# %%
resDir = Path("../results")
dataDir = Path("../data/MEG-resting-state")

# %%
datFil = list(dataDir.glob("*8002*min.mat"))[0]
print(datFil)

MEG = loadmat(datFil)
data = MEG["DK_timecourse"]
data.shape
# Out:
# ../data/MEG-resting-state/lcmv_result_8002-101_wo_filtering_min.mat
# (68, 35999)

# %% [markdown]
# The time course is 60 seconds, so the frequency is 600 Hz

# %% [markdown]
# ###  Data preprocessing

# %%
q = 5
dataN = decimate(data, q=q)
dataN = detrend(dataN)

# %% [markdown]
# ### HPF

# %%
fs = 120 #sampling frequency
fmin = 2 # 2Hz - 45Hz signal range, filter for this with hbp
fmax = 45 
hbp = firls(101, [0, 0.005, 0.006, 0.007, 0.008, 1], desired = np.array([0, 0, 1, 1, 0, 0]))
#hbp = firls(101, np.array([0, 0.2*fmin, 0.9*fmin, fmax-2, fmax+5, 60])*2/fs,
#           desired = np.array([0, 0, 1, 1, 0, 0])) #for detrending, a bandpass
dataHPF = lfilter(hbp, 1, dataN)

# %%
d, n = dataHPF.shape
for i in range(d):
    plt.plot(dataHPF[i, :])

# %%
d, n = dataHPF.shape
for i in range(d):
    plt.plot(dataN[i, 1000:])

# %% [markdown]
# ## Detection on data with screening and no HPF

# %%
paras = edict()
paras.Lmin = 200
paras.wh = 10
paras.MaxM = 20
paras.fct = 0.5
paras.r = 6
paras.freq = 120
paras.lamb = 1e-4
paras.T = 2
paras.is_detrend = False
paras.decimateRate = None
paras.kappa = 2.77
paras.downRate = 20

# %%
detRaw = TVDNDetect1(Ymat=dataN, dataType="MEG", 
                     saveDir=None, #"MEGst02", 
                     fName="MEG1",
                     showProgress=True, 
                     MaxM=paras.MaxM,
                     Lmin=paras.Lmin, 
                     lamb=paras.lamb, 
                     kappa=paras.kappa, 
                     freq=paras.freq,
                     r=paras.r,
                     T=paras.T,
                     is_detrend=paras.is_detrend,
                     decimateRate=paras.decimateRate, 
                     downRate=paras.downRate)
# Out:
# The parameters for detection are:
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'MEG1',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 2.77,
#  'lamb': 0.0001,
#  'nbasis': 10,
#  'r': 6}

# %%
detRaw.Screening(wh=paras.wh)
detRaw()
# Out:
# HBox(children=(IntProgress(value=0, description='Screening', max=7200, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=351, style=ProgressStyle(descriptio…

# %%
kappas = np.arange(1, 4, 0.001)
detRaw.TuningKappa(kappas)
# Out:
# HBox(children=(IntProgress(value=0, max=21), HTML(value='')))

# %%
detRaw.UpdateEcpts(6)
print(detRaw)
detRaw.PlotEcpts()
detRaw.PlotEigenCurve()
# Out:
# +-------------+---------------------------------------+------------------------+------+
# | Num of CPTs |             Estiamted CPTs            |          MSE           | Rank |
# +-------------+---------------------------------------+------------------------+------+
# |      6      | [1624. 3594. 5287. 5571. 6118. 6342.] | 1.4521594912169216e+17 |  6   |
# +-------------+---------------------------------------+------------------------+------+

# %%
detRaw.UpdateEcpts(7)
print(detRaw)
detRaw.PlotEcpts()
detRaw.PlotEigenCurve()
# Out:
# +-------------+---------------------------------------------+------------------------+------+
# | Num of CPTs |                Estiamted CPTs               |          MSE           | Rank |
# +-------------+---------------------------------------------+------------------------+------+
# |      7      | [1624. 3594. 3949. 5287. 5571. 6118. 6342.] | 2.2159587974676278e+18 |  6   |
# +-------------+---------------------------------------------+------------------------+------+

# %%
detRaw.UpdateEcpts(8)
print(detRaw)
detRaw.PlotEcpts()
detRaw.PlotEigenCurve()
# Out:
# +-------------+---------------------------------------------------+----------------------+------+
# | Num of CPTs |                   Estiamted CPTs                  |         MSE          | Rank |
# +-------------+---------------------------------------------------+----------------------+------+
# |      8      | [ 543. 1979. 3594. 3949. 5287. 5571. 6118. 6342.] | 5.19975179576531e+17 |  6   |
# +-------------+---------------------------------------------------+----------------------+------+

# %%
detRaw.UpdateEcpts(8)
print(detRaw)
detRaw.PlotEcpts()
detRaw.PlotEigenCurve()
# Out:
# +-------------+---------------------------------------------------+----------------------+------+
# | Num of CPTs |                   Estiamted CPTs                  |         MSE          | Rank |
# +-------------+---------------------------------------------------+----------------------+------+
# |      8      | [ 543. 1979. 3594. 3949. 5287. 5571. 6118. 6342.] | 5.19975179576531e+17 |  6   |
# +-------------+---------------------------------------------------+----------------------+------+

# %%
detRaw.UpdateEcpts(9)
print(detRaw)
detRaw.PlotEcpts()
detRaw.PlotEigenCurve()
# Out:
# +-------------+---------------------------------------------------------+------------------------+------+
# | Num of CPTs |                      Estiamted CPTs                     |          MSE           | Rank |
# +-------------+---------------------------------------------------------+------------------------+------+
# |      9      | [ 543. 1979. 2500. 2736. 3594. 5287. 5571. 6118. 6342.] | 4.0319628248403064e+16 |  6   |
# +-------------+---------------------------------------------------------+------------------------+------+

# %%
detRaw.UpdateEcpts(7)
print(detRaw)
detRaw.PlotEcpts()
detRaw.PlotEigenCurve()
# Out:
# +-------------+---------------------------------------------+------------------------+------+
# | Num of CPTs |                Estiamted CPTs               |          MSE           | Rank |
# +-------------+---------------------------------------------+------------------------+------+
# |      7      | [1624. 3594. 3949. 5287. 5571. 6118. 6342.] | 2.2159587974676278e+18 |  6   |
# +-------------+---------------------------------------------+------------------------+------+

# %%
detRaw.UpdateEcpts(7)
print(detRaw)
detRaw.PlotEcpts()
detRaw.PlotEigenCurve()
# Out:
# +-------------+---------------------------------------------+------------------------+------+
# | Num of CPTs |                Estiamted CPTs               |          MSE           | Rank |
# +-------------+---------------------------------------------+------------------------+------+
# |      7      | [1624. 3594. 3949. 5287. 5571. 6118. 6342.] | 2.2159587974676278e+18 |  6   |
# +-------------+---------------------------------------------+------------------------+------+

# %%
detRaw.UpdateEcpts(7)
print(detRaw)
detRaw.PlotEcpts()
detRaw.PlotEigenCurve()
# Out:
# +-------------+---------------------------------------------+------------------------+------+
# | Num of CPTs |                Estiamted CPTs               |          MSE           | Rank |
# +-------------+---------------------------------------------+------------------------+------+
# |      7      | [1624. 3594. 3949. 5287. 5571. 6118. 6342.] | 2.2159587974676278e+18 |  6   |
# +-------------+---------------------------------------------+------------------------+------+

# %%
detRaw.UpdateEcpts(7)
print(detRaw)
detRaw.PlotEcpts()
detRaw.PlotEigenCurve()
# Out:
# +-------------+---------------------------------------------+------------------------+------+
# | Num of CPTs |                Estiamted CPTs               |          MSE           | Rank |
# +-------------+---------------------------------------------+------------------------+------+
# |      7      | [1624. 3594. 3949. 5287. 5571. 6118. 6342.] | 2.2159587974676278e+18 |  6   |
# +-------------+---------------------------------------------+------------------------+------+

# %%
detRaw.PlotEigenCurve()

# %%
detRaw.kappas[detRaw.numchgs==9]
# Out:
# array([2.777, 2.778, 2.779, 2.78 , 2.781, 2.782, 2.783, 2.784, 2.785,
#        2.786, 2.787, 2.788, 2.789, 2.79 , 2.791, 2.792, 2.793, 2.794,
#        2.795, 2.796, 2.797, 2.798, 2.799, 2.8  , 2.801, 2.802, 2.803,
#        2.804, 2.805, 2.806, 2.807, 2.808, 2.809, 2.81 , 2.811, 2.812,
#        2.813, 2.814, 2.815, 2.816, 2.817, 2.818, 2.819, 2.82 , 2.821,
#        2.822, 2.823, 2.824, 2.825, 2.826, 2.827, 2.828, 2.829, 2.83 ,
#        2.831, 2.832, 2.833, 2.834, 2.835, 2.836, 2.837, 2.838, 2.839,
#        2.84 , 2.841, 2.842, 2.843, 2.844, 2.845, 2.846, 2.847, 2.848,
#        2.849, 2.85 , 2.851, 2.852, 2.853, 2.854, 2.855, 2.856, 2.857,
#        2.858])

# %% [markdown]
# ## Detection on data with no  HPF and no screening

# %%
detRawNo = TVDNDetect1(Ymat=dataN, dataType="MEG", 
                     saveDir="MEGeye-st02-rank6", 
                     fName="MEGmin",
                     showProgress=True, 
                     MaxM=paras.MaxM,
                     Lmin=paras.Lmin, 
                     lamb=paras.lamb, 
                     kappa=paras.kappa, 
                     freq=paras.freq,
                     r=paras.r,
                     T=paras.T,
                     is_detrend=paras.is_detrend,
                     decimateRate=paras.decimateRate, 
                     downRate=paras.downRate)
# Out:
# The parameters for detection are:
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'MEGmin',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 1,
#  'lamb': 0.0001,
#  'nbasis': 10,
#  'r': 6}

# %%
detRawNo()
# Out:
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=7200, style=ProgressStyle(descripti…
# Save Main Results at MEGeye-st02-rank6/MEGmin_Rank6.pkl.

# %%
kappas = np.linspace(1, 4, 1000)
detRawNo.TuningKappa(kappas)
# Out:
# HBox(children=(IntProgress(value=0, max=21), HTML(value='')))

# %%
detRawNo.UpdateEcpts(6)
print(detRawNo)
detRawNo.PlotEcpts(GT=gtSt02.cpts)
# Out:
# +-------------+---------------------------------------+-------------------+------+
# | Num of CPTs |             Estiamted CPTs            |        MSE        | Rank |
# +-------------+---------------------------------------+-------------------+------+
# |      6      | [ 466. 1600. 3030. 4367. 5512. 7000.] | 5.735169278207809 |  6   |
# +-------------+---------------------------------------+-------------------+------+

# %%
detRawNo.PlotEigenCurve()

# %%
detRawNo.kappas[detRawNo.numchgs==6]
# Out:
# array([1.48948949, 1.49249249, 1.4954955 , 1.4984985 , 1.5015015 ,
#        1.5045045 , 1.50750751, 1.51051051, 1.51351351, 1.51651652,
#        1.51951952, 1.52252252, 1.52552553, 1.52852853, 1.53153153,
#        1.53453453, 1.53753754, 1.54054054, 1.54354354, 1.54654655,
#        1.54954955])
