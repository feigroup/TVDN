# %%
import sys
sys.path.append("/home/huaqingj/MyResearch/TVDN")

# %%
from pyTVDN import TVDNDetect, TVDNRankTuning
from pathlib import Path
from scipy.io import loadmat
from scipy.signal import detrend
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pyTVDN.tmpUtils import *
# %matplotlib inline

# %%
from pprint import pprint
import pickle
from easydict import EasyDict as edict
import warnings
from pyTVDN.TVDNutils import *
from pyTVDN.utils import in_notebook
if in_notebook():
    from tqdm import tqdm_notebook as tqdm
else:
    from tqdm import tqdm

class TVDNDetect1(TVDNDetect):
    def SmoothEst(self):
        if self.nYmat is None:
            self._Preprocess()
        d, n = self.nYmat.shape
        acTime = n / self.paras.freq
        self.ptime = np.linspace(0, acTime, n)
        self.time = np.linspace(0, self.paras.T, n)
        divNum = 100
        if self.smoothType == "bspline":
            self.dXmat = np.zeros((d, n))
            self.Xmat = np.zeros((d, n))
            if n%divNum == 0:
                numLoop = int(n/divNum)
            else:
                numLoop = int(n/divNum) + 1
            for i in range(numLoop):
                if (i+1)*divNum <= n:
                    low = i*divNum
                    up = (i+1)*divNum
                else:
                    low = i*divNum
                    up = n
                self.dXmat[:, low:up], self.Xmat[:, low:up] = GetBsplineEst(self.nYmat[:, low:up], self.time[low:up], 
                                                                            lamb=self.paras.lamb)
        elif self.smoothType == "fourier":
            self.dXmat, self.Xmat = GetFourierEst(self.nYmat, self.time, nbasis=self.paras.nbasis)

# %%
resDir = Path("../results")
dataDir = Path("../data/newMEGdata")

# %%
datFil = list(dataDir.glob("*02*min.mat"))[0]
datFil
# Out:
# PosixPath('../data/newMEGdata/lcmv_result_R2868E_02-st_wo_filtering_min.mat')

# %%
gtF = list(dataDir.glob("*02_st.txt"))[0]
gtSt02 = time2pts(txt2Time(gtF), timeLims.st02)

# %%
np.diff(gtSt02.cpts)
# Out:
# array([1034, 1345, 1392, 1253, 1365])

# %%
from scipy.signal import lfilter, firls, decimate

# %%
q = 10

# %% [markdown]
# ## Plot the data

# %%
MEG = loadmat(datFil)

# %%
data = MEG["DK_timecourse"]

# %% [markdown]
# The time course is 60 seconds, so the frequency is 1200 Hz

# %%
d, n = data.shape

# %% [markdown]
# ###  Data preprocessing

# %%
dataN = decimate(data, q=q)
dataN = detrend(dataN)

# %% [markdown]
# ### HPF

# %%
fs = 120 #sampling frequency
fmin = 2 # 2Hz - 45Hz signal range, filter for this with hbp
fmax = 45
hbp = firls(101, np.array([0, 0.2*fmin, 0.9*fmin, fmax-2, fmax+5, 60])*2/fs,
           desired = np.array([0, 0, 1, 1, 0, 0])) #for detrending, a bandpass

# %%
dataHPF = lfilter(hbp, 1, dataN)

# %% [markdown]
# ## Detection on data without HPF

# %%
paras = edict()
paras.Lmin = 200
paras.wh = 10
paras.MaxM = 20
paras.fct = 0.5
paras.r = 8 
paras.freq = 120
paras.lamb = 2e-3
paras.T = 2
paras.is_detrend = False
paras.decimateRate = None
paras.kappa = 1
paras.downRate = 20

# %% [markdown]
# **Best**
#
# wh = 10
#
# numCpt=8 or 9
#
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'MEG1',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 1,
#  'lamb': 0.002,
#  'nbasis': 10,
#  'r': 8}

# %%
detRaw = TVDNDetect(Ymat=dataN, dataType="MEG", 
                     saveDir=None, #"MEGst02", 
                     fName="MEG1",
                     showProgress=True, 
                     MaxM=paras.MaxM,
                     Lmin=paras.Lmin, 
                     lamb=paras.lamb, 
                     kappa=paras.kappa, 
                     freq=paras.freq,
                     r=paras.r,
                     T=paras.T,
                     is_detrend=paras.is_detrend,
                     decimateRate=paras.decimateRate, 
                     downRate=paras.downRate)
# Out:
# The parameters for detection are:
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'MEG1',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 1,
#  'lamb': 0.002,
#  'nbasis': 10,
#  'r': 8}

# %%
detRaw.Screening(wh=paras.wh)
# Out:
# HBox(children=(IntProgress(value=0, description='Screening', max=7200, style=ProgressStyle(description_width='…

# %%
detRaw()
# Out:
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=217, style=ProgressStyle(descriptio…

# %%
kappas = np.linspace(1, 4, 1000)
detRaw.TuningKappa(kappas)
# Out:
# HBox(children=(IntProgress(value=0, max=21), HTML(value='')))

# %%
detRaw.UpdateEcpts(8)
print(detRaw)
detRaw.PlotEcpts(GT=gtSt02.cpts)
# Out:
# +-------------+---------------------------------------------------+-------------------+------+
# | Num of CPTs |                   Estiamted CPTs                  |        MSE        | Rank |
# +-------------+---------------------------------------------------+-------------------+------+
# |      8      | [ 564. 1059. 1659. 2787. 3503. 4167. 5579. 6670.] | 1.631264860695337 |  8   |
# +-------------+---------------------------------------------------+-------------------+------+

# %%
detRaw.UpdateEcpts(9)
print(detRaw)
detRaw.PlotEcpts(GT=gtSt02.cpts)
# Out:
# +-------------+---------------------------------------------------------+--------------------+------+
# | Num of CPTs |                      Estiamted CPTs                     |        MSE         | Rank |
# +-------------+---------------------------------------------------------+--------------------+------+
# |      9      | [ 564. 1059. 1659. 2787. 3503. 4167. 5713. 6353. 6740.] | 1.4968815612345971 |  8   |
# +-------------+---------------------------------------------------------+--------------------+------+

# %% [markdown]
# ## Detection after HPF under hyperparameters set1

# %%
paras = edict()
paras.Lmin = 200
paras.wh = 10
paras.MaxM = 20
paras.fct = 0.5
paras.r = 8 
paras.freq = 120
paras.lamb = 1e-3
paras.T = 2
paras.is_detrend = False
paras.decimateRate = None
paras.kappa = 1
paras.downRate = 20

# %% [markdown]
# **Good**
#
# wh = 10
#
# numCpts = 10/(9, 10)
#
# The parameters for detection are:
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'HPF1',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 1,
#  'lamb': 0.001,
#  'nbasis': 10,
#  'r': 8/10}

# %%
detHPF = TVDNDetect(Ymat=dataHPF, dataType="MEG", 
                     saveDir=None, #"MEGst02", 
                     fName="HPF1",
                     showProgress=True, 
                     MaxM=paras.MaxM,
                     Lmin=paras.Lmin, 
                     lamb=paras.lamb, 
                     kappa=paras.kappa, 
                     freq=paras.freq,
                     r=paras.r,
                     T=paras.T,
                     is_detrend=paras.is_detrend,
                     decimateRate=paras.decimateRate, 
                     downRate=paras.downRate)
# Out:
# The parameters for detection are:
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'HPF1',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 1,
#  'lamb': 0.001,
#  'nbasis': 10,
#  'r': 8}

# %%
detHPF.Screening(wh=paras.wh)#
# Out:
# HBox(children=(IntProgress(value=0, description='Screening', max=7200, style=ProgressStyle(description_width='…

# %%
detHPF()
# Out:
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=233, style=ProgressStyle(descriptio…

# %%
kappas = np.linspace(1, 4, 1000)
detHPF.TuningKappa(kappas)
# Out:
# HBox(children=(IntProgress(value=0, max=21), HTML(value='')))

# %%
detHPF.UpdateEcpts(10)
print(detHPF)
detHPF.PlotEcpts(GT=gtSt02.cpts)
# Out:
# +-------------+---------------------------------------------------------------+--------------------+------+
# | Num of CPTs |                         Estiamted CPTs                        |        MSE         | Rank |
# +-------------+---------------------------------------------------------------+--------------------+------+
# |      10     | [ 419. 1025. 1590. 2222. 2895. 3708. 4236. 5402. 6212. 6814.] | 0.9657961275048816 |  8   |
# +-------------+---------------------------------------------------------------+--------------------+------+

# %% [markdown]
# ## Detection after HPF under hyperparameters set2

# %%
paras = edict()
paras.Lmin = 200
paras.wh = 10
paras.MaxM = 20
paras.fct = 0.5
paras.r = 10 
paras.freq = 120
paras.lamb = 1e-3
paras.T = 2
paras.is_detrend = False
paras.decimateRate = None
paras.kappa = 1
paras.downRate = 20

# %% [markdown]
# **Good**
#
# wh = 10
#
# numCpts = 10/(9, 10)
#
# The parameters for detection are:
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'HPF1',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 1,
#  'lamb': 0.001,
#  'nbasis': 10,
#  'r': 8/10}

# %%
detHPF = TVDNDetect(Ymat=dataHPF, dataType="MEG", 
                     saveDir=None, #"MEGst02", 
                     fName="HPF1",
                     showProgress=True, 
                     MaxM=paras.MaxM,
                     Lmin=paras.Lmin, 
                     lamb=paras.lamb, 
                     kappa=paras.kappa, 
                     freq=paras.freq,
                     r=paras.r,
                     T=paras.T,
                     is_detrend=paras.is_detrend,
                     decimateRate=paras.decimateRate, 
                     downRate=paras.downRate)
# Out:
# The parameters for detection are:
# {'Lmin': 200,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': None,
#  'downRate': 20,
#  'fName': 'HPF1',
#  'fct': 0.5,
#  'freq': 120,
#  'is_detrend': False,
#  'kappa': 1,
#  'lamb': 0.001,
#  'nbasis': 10,
#  'r': 10}

# %%
detHPF.Screening(wh=paras.wh)#
# Out:
# HBox(children=(IntProgress(value=0, description='Screening', max=7200, style=ProgressStyle(description_width='…

# %%
detHPF()
# Out:
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=227, style=ProgressStyle(descriptio…

# %%
kappas = np.linspace(1, 4, 1000)
detHPF.TuningKappa(kappas)
# Out:
# HBox(children=(IntProgress(value=0, max=21), HTML(value='')))

# %%
detHPF.UpdateEcpts(9)
print(detHPF)
detHPF.PlotEcpts(GT=gtSt02.cpts)
# Out:
# +-------------+---------------------------------------------------------+--------------------+------+
# | Num of CPTs |                      Estiamted CPTs                     |        MSE         | Rank |
# +-------------+---------------------------------------------------------+--------------------+------+
# |      9      | [ 713. 1306. 2080. 2860. 3708. 4202. 5402. 6212. 6928.] | 0.9715988551219865 |  10  |
# +-------------+---------------------------------------------------------+--------------------+------+

# %%
detHPF.UpdateEcpts(10)
print(detHPF)
detHPF.PlotEcpts(GT=gtSt02.cpts)
# Out:
# +-------------+---------------------------------------------------------------+--------------------+------+
# | Num of CPTs |                         Estiamted CPTs                        |        MSE         | Rank |
# +-------------+---------------------------------------------------------------+--------------------+------+
# |      10     | [ 420. 1025. 1590. 2222. 2966. 3986. 4808. 5785. 6315. 6928.] | 0.9765308870160296 |  10  |
# +-------------+---------------------------------------------------------------+--------------------+------+
