# %%
import sys
sys.path.append("/home/huaqingj/MyResearch/TVDN")

# %%
from pyTVDN import TVDNDetect, TVDNRankTuning
from pathlib import Path
from scipy.io import loadmat
from scipy.signal import detrend
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import pickle
# %matplotlib inline
plt.style.use('ggplot')

# %%
from scipy.signal import lfilter, firls, decimate

# %%
def obtainAbswU(res):
    optDet = res.DetectObj
    eigVecs = optDet.midRes.eigVecs[:, :optDet.paras.r]
    kpidxs = np.concatenate([[0], optDet.ecpts]).astype(np.int)
    eigVals = optDet.RecResCur.LamMs[:, kpidxs]
    wU = eigVecs.dot(eigVals)
    return np.abs(wU)

# %%
saveDir = Path("./fMRIHPFs")

# %%
fils = list(saveDir.glob("*.pkl"))

# %%
fils = sorted(fils, key=lambda x: int(x.stem.split("_")[-1]))

# %% [markdown]
# ## fMRI 5

# %%
with open(fils[4], "rb") as f:
    res = pickle.load(f)

# %%
abswU = obtainAbswU(res)
np.savetxt("./midRess/fMRI5wU.txt", abswU)

# %%
res
# Out:
# {'minErr': 0.8149651482888159,
#  'optRank': 6,
#  'optKappa': array([1.72, 1.73, 1.74, 1.75, 1.76, 1.77, 1.78, 1.79, 1.8 , 1.81]),
#  'DetectObj': <pyTVDN.TVDNclass.TVDNDetect at 0x7fa1150cf3c8>}

# %% [markdown]
# ### Change points

# %%
print(res.DetectObj)
# Out:
# +-------------+-------------------------------------------+--------------------+------+
# | Num of CPTs |               Estiamted CPTs              |        MSE         | Rank |
# +-------------+-------------------------------------------+--------------------+------+
# |      8      | [ 22.  51.  67.  81.  93. 112. 124. 141.] | 0.8149651482888159 |  6   |
# +-------------+-------------------------------------------+--------------------+------+

# %%
res.DetectObj.PlotEcpts()

# %% [markdown]
# ### Reconstructed curve , best to worst

# %%
res.DetectObj.PlotRecCurve(is_smoothCurve=1)
# Out:
# array([ 7, 34, 19, 50, 62])

# %% [markdown]
# ### EigenValue

# %%
res.DetectObj.PlotEigenCurve()

# %% [markdown]
# ## fMRI 15

# %%
with open(fils[14], "rb") as f:
    res = pickle.load(f)

# %%
abswU = obtainAbswU(res)
np.savetxt("./midRess/fMRI15wU.txt", abswU)

# %%
res
# Out:
# {'minErr': 1.1428154173212106,
#  'optRank': 4,
#  'optKappa': array([1.48, 1.49, 1.5 , 1.51, 1.52, 1.53, 1.54, 1.55, 1.56, 1.57, 1.58,
#         1.59, 1.6 ]),
#  'DetectObj': <pyTVDN.TVDNclass.TVDNDetect at 0x7fa0d05e5630>}

# %% [markdown]
# ### Change points

# %%
print(res.DetectObj)
# Out:
# +-------------+-------------------+--------------------+------+
# | Num of CPTs |   Estiamted CPTs  |        MSE         | Rank |
# +-------------+-------------------+--------------------+------+
# |      4      | [27. 62. 70. 88.] | 1.1428154173212106 |  4   |
# +-------------+-------------------+--------------------+------+

# %%
res.DetectObj.PlotEcpts()

# %% [markdown]
# ### Reconstructed curve , best to worst

# %%
res.DetectObj.PlotRecCurve(is_smoothCurve=1)
# Out:
# array([73, 13, 67, 58, 16])

# %% [markdown]
# ### EigenValue

# %%
res.DetectObj.PlotEigenCurve()

# %% [markdown]
# ## fMRI 58

# %%
with open(fils[57], "rb") as f:
    res = pickle.load(f)

# %%
res
# Out:
# {'minErr': 0.8413868615102968,
#  'optRank': 2,
#  'optKappa': array([1.03, 1.04]),
#  'DetectObj': <pyTVDN.TVDNclass.TVDNDetect at 0x7fa0d0a96438>}

# %% [markdown]
# ### Change points

# %%
print(res.DetectObj)
# Out:
# +-------------+--------------------------------------+--------------------+------+
# | Num of CPTs |            Estiamted CPTs            |        MSE         | Rank |
# +-------------+--------------------------------------+--------------------+------+
# |      7      | [  7.  33.  44.  78. 100. 104. 148.] | 0.8413868615102968 |  2   |
# +-------------+--------------------------------------+--------------------+------+

# %%
res.DetectObj.PlotEcpts()

# %% [markdown]
# ### Reconstructed curve , best to worst

# %%
res.DetectObj.PlotRecCurve(is_smoothCurve=1)
# Out:
# array([59, 73, 32, 33,  7])

# %% [markdown]
# ### EigenValue

# %%
res.DetectObj.PlotEigenCurve()

# %% [markdown]
# ## fMRI 70

# %%
with open(fils[69], "rb") as f:
    res = pickle.load(f)

# %%
abswU = obtainAbswU(res)
np.savetxt("./midRess/fMRI70wU.txt", abswU)

# %%
res
# Out:
# {'minErr': 0.7797816010712307,
#  'optRank': 8,
#  'optKappa': array([1.28, 1.29, 1.3 , 1.31, 1.32, 1.33, 1.34, 1.35, 1.36, 1.37, 1.38,
#         1.39, 1.4 , 1.41, 1.42, 1.43, 1.44, 1.45, 1.46, 1.47, 1.48, 1.49,
#         1.5 , 1.51, 1.52, 1.53, 1.54, 1.55, 1.56, 1.57, 1.58, 1.59, 1.6 ,
#         1.61, 1.62, 1.63, 1.64, 1.65, 1.66, 1.67, 1.68, 1.69]),
#  'DetectObj': <pyTVDN.TVDNclass.TVDNDetect at 0x7fa0d0917d30>}

# %% [markdown]
# ### Change points

# %%
print(res.DetectObj)
# Out:
# +-------------+-----------------------------------------------------+--------------------+------+
# | Num of CPTs |                    Estiamted CPTs                   |        MSE         | Rank |
# +-------------+-----------------------------------------------------+--------------------+------+
# |      10     | [ 15.  31.  41.  57.  71.  86.  98. 110. 124. 139.] | 0.7797816010712307 |  8   |
# +-------------+-----------------------------------------------------+--------------------+------+

# %%
res.DetectObj.PlotEcpts()

# %% [markdown]
# ### Reconstructed curve , best to worst

# %%
res.DetectObj.PlotRecCurve(is_smoothCurve=1)
# Out:
# array([83, 40, 24, 54, 72])

# %% [markdown]
# ### EigenValue

# %%
res.DetectObj.PlotEigenCurve()

# %% [markdown]
# ## fMRI 149

# %%
with open(fils[148], "rb") as f:
    res = pickle.load(f)

# %%
abswU = obtainAbswU(res)
np.savetxt("./midRess/fMRI149wU.txt", abswU)

# %%
res
# Out:
# {'minErr': 0.6992326240692475,
#  'optRank': 12,
#  'optKappa': array([1.  , 1.01, 1.02, 1.03, 1.04]),
#  'DetectObj': <pyTVDN.TVDNclass.TVDNDetect at 0x7fa0d07b2160>}

# %% [markdown]
# ### Change points

# %%
print(res.DetectObj)
# Out:
# +-------------+-------------------------------------------+--------------------+------+
# | Num of CPTs |               Estiamted CPTs              |        MSE         | Rank |
# +-------------+-------------------------------------------+--------------------+------+
# |      8      | [ 14.  29.  45.  60.  88.  99. 120. 133.] | 0.6992326240692475 |  12  |
# +-------------+-------------------------------------------+--------------------+------+

# %%
res.DetectObj.PlotEcpts()

# %% [markdown]
# ### Reconstructed curve , best to worst

# %%
res.DetectObj.PlotRecCurve(is_smoothCurve=1)
# Out:
# array([22,  1, 13,  4, 32])

# %% [markdown]
# ### EigenValue

# %%
res.DetectObj.PlotEigenCurve()

# %% [markdown]
# ## fMRI 230

# %%
with open(fils[229], "rb") as f:
    res = pickle.load(f)

# %%
abswU = obtainAbswU(res)
np.savetxt("./midRess/fMRI230wU.txt", abswU)

# %%
res
# Out:
# {'minErr': 0.8162153793454388,
#  'optRank': 12,
#  'optKappa': array([1.36, 1.37]),
#  'DetectObj': <pyTVDN.TVDNclass.TVDNDetect at 0x7fa0d0aa1160>}

# %% [markdown]
# ### Change points

# %%
print(res.DetectObj)
# Out:
# +-------------+---------------------------------+--------------------+------+
# | Num of CPTs |          Estiamted CPTs         |        MSE         | Rank |
# +-------------+---------------------------------+--------------------+------+
# |      6      | [ 33.  56.  70.  94. 123. 133.] | 0.8162153793454388 |  12  |
# +-------------+---------------------------------+--------------------+------+

# %%
res.DetectObj.PlotEcpts()

# %% [markdown]
# ### Reconstructed curve , best to worst

# %%
res.DetectObj.PlotRecCurve(is_smoothCurve=1)
# Out:
# array([34, 74, 18, 69, 43])

# %% [markdown]
# ### EigenValue

# %%
res.DetectObj.PlotEigenCurve()
