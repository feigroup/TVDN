# %%
import numpy as np
import numpy.random as npr
import matplotlib.pyplot as plt
import rpy2.robjects as robj
import pyreadr
# %matplotlib inline
from easydict import EasyDict as edict
from tqdm import tqdm_notebook as tqdm
import sys
import time as Time
import pickle
from numpy.linalg import inv
from pathlib import Path
from scipy.io import loadmat
from easydict import EasyDict as edict
from scipy.signal import detrend

# %%
sys.path.append("/home/huaqingj/MyResearch/TVDN")
from pyTVDN.TVDNutils import *
from pyTVDN import TVDNDetect
from pyTVDN.Rfuns import decimate_R
from pyTVDN.TVDNclass import TVDNDetect
from pyTVDN.TVDNKappaTuning import TVDNKappaTuningCV

# %%
resDir = Path("../results")
dataDir = Path("../data")
filname = Path("subj2.mat")
MEG = loadmat(dataDir/filname)["DK_timecourse"]
Ymat = MEG

# %%
kappas = np.linspace(2, 3.5, 100)

# %%
bestKappa = TVDNKappaTuningCV(kappas, Ymat, numFold=3600, randomSel=True, numTimes=100, wh=30, dataType="MEG", saveDir=None, r=8, MaxM=20)
# Out:
# R[write to console]:
# Attaching package: ‘signal’
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     filter, poly
# HBox(children=(IntProgress(value=0, description='Cross Validation', style=ProgressStyle(description_width='ini…

# %% [markdown]
# ### Detect under the kappa obtained from `TVDNKappaTuningCV`

# %%
MEGdet = TVDNDetect(Ymat=Ymat, saveDir=None, dataType="MEG", fName="subj2", r=8, kappa=bestKappa, freq=60, MaxM=20)
# Out:
# The parameters for detection are:
# {'Lmin': 60,
#  'MaxM': 20,
#  'T': 2,
#  'decimateRate': 10,
#  'downRate': 20,
#  'fName': 'subj2',
#  'fct': 0.5,
#  'freq': 60,
#  'is_detrend': False,
#  'kappa': 2.5757575757575757,
#  'lamb': 0.0001,
#  'plotfct': 30,
#  'r': 8}

# %%
MEGdet.Screening(wh=30)
# Out:
# HBox(children=(IntProgress(value=0, description='Screening', max=3600, style=ProgressStyle(description_width='…

# %%
MEGdet()
# Out:
# HBox(children=(IntProgress(value=0, description='Dynamic Programming', max=50, style=ProgressStyle(description…

# %%
print(MEGdet)
# Out:
# +-------------+------------------------------------------------------------------------+--------------------+------+
# | Num of CPTs |                             Estiamted CPTs                             |        MSE         | Rank |
# +-------------+------------------------------------------------------------------------+--------------------+------+
# |      20     | [ 163  357  519  638  768  980 1176 1361 1497 1598 1842 2014 2159 2342 | 0.5593214179142989 |  8   |
# |             |                     2477 2671 2899 3082 3207 3386]                     |                    |      |
# +-------------+------------------------------------------------------------------------+--------------------+------+

# %%
MEGdet.PlotRecCurve([43, 44, 59])

# %% [markdown]
# ### The results under the `kappa`  from the MSE errors

# %%
MEGdet.TuningKappa(kappas)
# Out:
# HBox(children=(IntProgress(value=0, max=21), HTML(value='')))

# %%
MEGdet.UpdateEcpts()
print(MEGdet)
# Out:
# +-------------+--------------------------------------------------------------------------+-------------------+------+
# | Num of CPTs |                              Estiamted CPTs                              |        MSE        | Rank |
# +-------------+--------------------------------------------------------------------------+-------------------+------+
# |      14     | [ 196.  519.  768. 1053. 1287. 1497. 1598. 1842. 2105. 2477. 2671. 2899. | 0.428335587675283 |  8   |
# |             |                               3082. 3386.]                               |                   |      |
# +-------------+--------------------------------------------------------------------------+-------------------+------+

# %%
MEGdet.PlotRecCurve([43, 44, 59])
